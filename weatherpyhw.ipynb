# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)


# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
cities
# Out:
# ['halifax',
#  'mataura',
#  'port-gentil',
#  'huarmey',
#  'salalah',
#  'carira',
#  'ushuaia',
#  'taolanaro',
#  'punta arenas',
#  'raudeberg',
#  'luwuk',
#  'castro',
#  'zhangjiakou',
#  'kimparana',
#  'kununurra',
#  'peniche',
#  'barentsburg',
#  'bredasdorp',
#  'busselton',
#  'sorland',
#  'saint-joseph',
#  'kapaa',
#  'chikoy',
#  'arraial do cabo',
#  'vaini',
#  'gizo',
#  'tyazhinskiy',
#  'adre',
#  'pisco',
#  'margate',
#  'butaritari',
#  'hambantota',
#  'hermanus',
#  'hithadhoo',
#  'srednekolymsk',
#  'mutsamudu',
#  'canandaigua',
#  'cape town',
#  'college',
#  'palabuhanratu',
#  'saleaula',
#  'natal',
#  'mahebourg',
#  'mar del plata',
#  'surt',
#  'maniitsoq',
#  'puerto ayora',
#  'albany',
#  'plaeng yao',
#  'buala',
#  'qaanaaq',
#  'laguna',
#  'atuona',
#  'price',
#  'yulara',
#  'cagayan de tawi-tawi',
#  'bethel',
#  'birjand',
#  'port elizabeth',
#  'hami',
#  'chepareria',
#  'tiksi',
#  'goderich',
#  'kabul',
#  'namie',
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#cities = ["Paris", "Toronto", "London","New York"]

citydata=[]

 
    
for city in cities:
    try:
        print ("processing data for cities"+city)
        
        url=f"http://api.openweathermap.org/data/2.5/weather?q={city}&APPID={api_key}"
        city_weather=(requests.get(url).json())
        citylat=city_weather["coord"]["lat"]
        citylon=city_weather["coord"]["lon"]
        citymaxtmp=city_weather["main"]["temp_max"]
        cityhumidity=city_weather["main"]["humidity"]
        citywind=city_weather["wind"]["speed"]
        cityclouds=city_weather["clouds"]["all"]

        citydata.append({
            "city":city,
            "Latitude":citylat,
            "Longitutde":citylon,
            "temperature":citymaxtmp,
            "humidity":cityhumidity,
            "wind":citywind,
            "clouds":cityclouds

        })
   

    except: 
        print ("city not found pass")
        pass

citydata
# Out:
# processing data for citieshalifax
# processing data for citiesmataura
# processing data for citiesport-gentil
# processing data for citieshuarmey
# processing data for citiessalalah
# processing data for citiescarira
# processing data for citiesushuaia
# processing data for citiestaolanaro
# city not found pass
# processing data for citiespunta arenas
# processing data for citiesraudeberg
# processing data for citiesluwuk
# processing data for citiescastro
# processing data for citieszhangjiakou
# processing data for citieskimparana
# processing data for citieskununurra
# processing data for citiespeniche
# processing data for citiesbarentsburg
# city not found pass
# processing data for citiesbredasdorp
# processing data for citiesbusselton
# processing data for citiessorland
# processing data for citiessaint-joseph
# processing data for citieskapaa
# processing data for citieschikoy
# city not found pass
# processing data for citiesarraial do cabo
# processing data for citiesvaini
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame(citydata)
city_df
# Out:
#      Latitude  Longitutde              city  clouds  humidity  temperature  \
# 0       44.65      -63.58           halifax      75        86       275.37
# 1      -46.19      168.86           mataura       0        71       283.71
# 2       -0.72        8.78       port-gentil      75        74       304.15
# 3      -10.07      -78.15           huarmey      58        55       298.48
# 4       17.01       54.10           salalah       1        24       299.15
# 5      -10.36      -37.70            carira       0        31       307.32
# 6      -54.81      -68.31           ushuaia      75        66       284.15
# 7      -53.16      -70.91      punta arenas      75        42       293.15
# 8       61.99        5.14         raudeberg      75        70       279.15
# 9       -0.95      122.79             luwuk      99        79       301.13
# 10     -42.48      -73.76            castro      75        77       290.15
# ...

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#plt.figure(figsize=(20,3))
plt.scatter(city_df["Latitude"], city_df["temperature"],color='r')

#plt.savefig("../Images/avg_state_rain.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["Latitude"], city_df["humiidty"],color='r')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["Latitude"], city_df["clouds"],color='r')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["Latitude"], city_df["wind"],color='r')
